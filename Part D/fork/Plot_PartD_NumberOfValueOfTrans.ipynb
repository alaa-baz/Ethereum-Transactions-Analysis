# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('out_avrOfValuOfTran_before.csv')

dataset = pd.DataFrame(data)

# %%
x = dataset['date']
y = list(dataset['val'])

# Create bars
plt.figure(figsize=(15,10))
plt.bar(x, y)

plt.xticks(rotation= 75)
plt.xlabel('Date before Fork')
plt.ylabel('Average of Value of transactions')

# Plot graph
plt.show()

# %%
data2 = pd.read_csv('out_avrOfValuOfTran_after.csv')

dataset2 = pd.DataFrame(data2)

# %%
x = dataset2['date']
y = list(dataset2['val'])

# Create bars
plt.figure(figsize=(15,10))
plt.bar(x, y)

plt.xticks(rotation= 75)
plt.xlabel('Date After Fork')
plt.ylabel('Average of Value of transactions')

# Plot graph
plt.show()
