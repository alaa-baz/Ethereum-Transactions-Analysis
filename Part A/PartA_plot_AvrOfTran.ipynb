# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#dataset = pd.ExcelFile('plot_PartA result.xlsx')
data = pd.read_csv('avrNumberOfTrans.csv')

dataset = pd.DataFrame(data)

# %%
#x_pos = np.arange(len(x))
x = dataset['date']
y = list(dataset['value'])

# Create bars
fig =plt.figure(figsize=(15,10))
plt.bar(x, y)

# Create names on the x-axis
plt.xticks(rotation= 70)

# Show graph
plt.show()
